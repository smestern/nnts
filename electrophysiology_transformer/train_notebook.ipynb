# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
#Clone repo
import os
import shutil
if os.path.exists("/content/nnts"):
  shutil.rmtree("/content/nnts")

os.chdir("/content")
# !git clone https://github.com/smestern/nnts.git
# Out:
# Cloning into 'nnts'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 64 (delta 21), reused 53 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 860.76 KiB | 27.77 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
import os
os.chdir("/content/nnts/electrophysiology_transformer")

# %%
import train

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train.main("/content/drive/MyDrive/nngan_trace_dataset_2000.joblib", "/content/drive/MyDrive/nnts_checkpoints/best_val.pt")
# Out:
# Using device: cuda
# Prepared 10000 windows from 1800 trials
#
# Starting training...
# Training: 100%|██████████| 562/562 [04:29<00:00,  2.08it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 1/2000 - Train Loss: 1.5924 | Val Loss: 1.5312
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 2/2000 - Train Loss: 1.5565 | Val Loss: 1.4949
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 3/2000 - Train Loss: 1.5161 | Val Loss: 1.4505
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 4/2000 - Train Loss: 1.4653 | Val Loss: 1.3714
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 5/2000 - Train Loss: 1.3999 | Val Loss: 1.3394
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 6/2000 - Train Loss: 1.3003 | Val Loss: 1.1780
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 7/2000 - Train Loss: 1.1678 | Val Loss: 0.9419
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.07it/s]
# Epoch 8/2000 - Train Loss: 1.0597 | Val Loss: 0.9904
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.08it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 9/2000 - Train Loss: 0.9789 | Val Loss: 0.7908
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 10/2000 - Train Loss: 0.9303 | Val Loss: 0.7315
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.08it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 11/2000 - Train Loss: 0.8741 | Val Loss: 0.6515
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 12/2000 - Train Loss: 0.8334 | Val Loss: 0.6113
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 13/2000 - Train Loss: 0.7929 | Val Loss: 0.5699
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.08it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 14/2000 - Train Loss: 0.7499 | Val Loss: 0.5613
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 15/2000 - Train Loss: 0.7285 | Val Loss: 0.5017
# Training: 100%|██████████| 562/562 [04:33<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 16/2000 - Train Loss: 0.6938 | Val Loss: 0.4845
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 17/2000 - Train Loss: 0.6654 | Val Loss: 0.4316
# Training: 100%|██████████| 562/562 [04:34<00:00,  2.05it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 18/2000 - Train Loss: 0.6261 | Val Loss: 0.4067
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 19/2000 - Train Loss: 0.6063 | Val Loss: 0.3849
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 20/2000 - Train Loss: 0.5792 | Val Loss: 0.3488
# Training: 100%|██████████| 562/562 [04:33<00:00,  2.06it/s]
# Epoch 21/2000 - Train Loss: 0.5523 | Val Loss: 0.3965
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 22/2000 - Train Loss: 0.5307 | Val Loss: 0.2799
# Training: 100%|██████████| 562/562 [04:34<00:00,  2.05it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 23/2000 - Train Loss: 0.5100 | Val Loss: 0.2609
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 24/2000 - Train Loss: 0.4927 | Val Loss: 0.2345
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 25/2000 - Train Loss: 0.4705 | Val Loss: 0.2101
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 26/2000 - Train Loss: 0.4534 | Val Loss: 0.2001
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 27/2000 - Train Loss: 0.4378 | Val Loss: 0.1971
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 28/2000 - Train Loss: 0.4270 | Val Loss: 0.1569
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 29/2000 - Train Loss: 0.4075 | Val Loss: 0.1373
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 30/2000 - Train Loss: 0.3921 | Val Loss: 0.1276
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 31/2000 - Train Loss: 0.3822 | Val Loss: 0.1117
# Training: 100%|██████████| 562/562 [04:33<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 32/2000 - Train Loss: 0.3700 | Val Loss: 0.1035
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 33/2000 - Train Loss: 0.3515 | Val Loss: 0.0818
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 34/2000 - Train Loss: 0.3413 | Val Loss: 0.0698
# Training: 100%|██████████| 562/562 [04:33<00:00,  2.06it/s]
# Epoch 35/2000 - Train Loss: 0.3294 | Val Loss: 0.1510
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 36/2000 - Train Loss: 0.3161 | Val Loss: 0.0608
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 37/2000 - Train Loss: 0.3021 | Val Loss: 0.0444
# Training: 100%|██████████| 562/562 [04:29<00:00,  2.08it/s]
# Epoch 38/2000 - Train Loss: 0.3073 | Val Loss: 0.1254
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 39/2000 - Train Loss: 0.2879 | Val Loss: 0.0227
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# Epoch 40/2000 - Train Loss: 0.2766 | Val Loss: 0.0363
# Training: 100%|██████████| 562/562 [04:29<00:00,  2.08it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 41/2000 - Train Loss: 0.2675 | Val Loss: 0.0194
# Training: 100%|██████████| 562/562 [04:34<00:00,  2.05it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 42/2000 - Train Loss: 0.2539 | Val Loss: -0.0007
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# Epoch 43/2000 - Train Loss: 0.2535 | Val Loss: 0.0351
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 44/2000 - Train Loss: 0.2402 | Val Loss: -0.0103
# Training: 100%|██████████| 562/562 [04:30<00:00,  2.08it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 45/2000 - Train Loss: 0.2305 | Val Loss: -0.0193
# Training: 100%|██████████| 562/562 [04:31<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 46/2000 - Train Loss: 0.2211 | Val Loss: -0.0413
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 47/2000 - Train Loss: 0.2137 | Val Loss: -0.0417
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.06it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 48/2000 - Train Loss: 0.2000 | Val Loss: -0.0616
# Training: 100%|██████████| 562/562 [04:34<00:00,  2.05it/s]
# Epoch 49/2000 - Train Loss: 0.1930 | Val Loss: -0.0559
# Training: 100%|██████████| 562/562 [04:32<00:00,  2.07it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 50/2000 - Train Loss: 0.1869 | Val Loss: -0.0677
# Saved checkpoint to checkpoint_epoch_50.pt
# Training: 100%|██████████| 562/562 [04:34<00:00,  2.05it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 51/2000 - Train Loss: 0.1765 | Val Loss: -0.0825
# Training:  28%|██▊       | 156/562 [01:16<03:06,  2.18it/s]
