# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
#Clone repo
import os
import shutil
if os.path.exists("/content/nnts"):
  shutil.rmtree("/content/nnts")

os.chdir("/content")
# !git clone https://github.com/smestern/nnts.git
# Out:
# Cloning into 'nnts'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 79 (delta 31), reused 62 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 864.17 KiB | 18.39 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
import os
os.chdir("/content/nnts/electrophysiology_transformer")

# %%
import train

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train.main("/content/drive/MyDrive/nngan_trace_dataset_2000.joblib", "/content/drive/MyDrive/nnts_checkpoints/best_val.pt", batch_size=32)
# Out:
# Using device: cuda
# Prepared 10000 windows from 1800 trials
# Resumed training from checkpoint: /content/drive/MyDrive/nnts_checkpoints/best_val.pt
#
# Starting training...
# Training: 100%|██████████| 281/281 [04:26<00:00,  1.05it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 1/2000 - Train Loss: -0.0806 | Val Loss: -0.2973
# Training: 100%|██████████| 281/281 [04:29<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 2/2000 - Train Loss: -0.0836 | Val Loss: -0.2978
# Training: 100%|██████████| 281/281 [04:31<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 3/2000 - Train Loss: -0.0794 | Val Loss: -0.3075
# Training: 100%|██████████| 281/281 [04:31<00:00,  1.04it/s]
# Epoch 4/2000 - Train Loss: -0.0911 | Val Loss: -0.3064
# Training: 100%|██████████| 281/281 [04:29<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 5/2000 - Train Loss: -0.0884 | Val Loss: -0.3078
# Training: 100%|██████████| 281/281 [04:30<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 6/2000 - Train Loss: -0.1005 | Val Loss: -0.3137
# Training: 100%|██████████| 281/281 [04:32<00:00,  1.03it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 7/2000 - Train Loss: -0.0964 | Val Loss: -0.3259
# Training: 100%|██████████| 281/281 [04:34<00:00,  1.02it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 8/2000 - Train Loss: -0.0948 | Val Loss: -0.3304
# Training: 100%|██████████| 281/281 [04:29<00:00,  1.04it/s]
# Epoch 9/2000 - Train Loss: -0.1018 | Val Loss: -0.3229
# Training: 100%|██████████| 281/281 [04:29<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 10/2000 - Train Loss: -0.1065 | Val Loss: -0.3331
# Training: 100%|██████████| 281/281 [04:30<00:00,  1.04it/s]
# Epoch 11/2000 - Train Loss: -0.1076 | Val Loss: -0.3259
# Training: 100%|██████████| 281/281 [04:31<00:00,  1.04it/s]
# Epoch 12/2000 - Train Loss: -0.1166 | Val Loss: -0.3138
# Training: 100%|██████████| 281/281 [04:29<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 13/2000 - Train Loss: -0.1046 | Val Loss: -0.3433
# Training: 100%|██████████| 281/281 [04:30<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 14/2000 - Train Loss: -0.1168 | Val Loss: -0.3447
# Training: 100%|██████████| 281/281 [04:33<00:00,  1.03it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 15/2000 - Train Loss: -0.1298 | Val Loss: -0.3542
# Training: 100%|██████████| 281/281 [04:32<00:00,  1.03it/s]
# Epoch 16/2000 - Train Loss: -0.1339 | Val Loss: -0.3108
# Training: 100%|██████████| 281/281 [04:33<00:00,  1.03it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 17/2000 - Train Loss: -0.1308 | Val Loss: -0.3615
# Training: 100%|██████████| 281/281 [04:30<00:00,  1.04it/s]
# Epoch 18/2000 - Train Loss: -0.1321 | Val Loss: -0.3402
# Training: 100%|██████████| 281/281 [04:29<00:00,  1.04it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt
# Epoch 19/2000 - Train Loss: -0.1328 | Val Loss: -0.3624
# Training: 100%|██████████| 281/281 [04:30<00:00,  1.04it/s]
# Epoch 20/2000 - Train Loss: -0.1414 | Val Loss: -0.3570
# Training: 100%|██████████| 281/281 [04:30<00:00,  1.04it/s]
