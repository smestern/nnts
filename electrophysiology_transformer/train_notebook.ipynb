# %%
# !pip install transformers

# %%
#Clone repo
import os
import shutil
if os.path.exists("/content/nnts"):
  shutil.rmtree("/content/nnts")

os.chdir("/content")
# !git clone https://github.com/smestern/nnts.git
# Out:
# Cloning into 'nnts'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 137 (delta 73), reused 86 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (137/137), 1.03 MiB | 3.89 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
import os
os.chdir("/content/nnts/electrophysiology_transformer")

# %%
import train

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train.main("/content/drive/MyDrive/nngan_trace_dataset_2000.joblib",
           "/content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt_epoch_35.pt_epoch_34.pt_epoch_18.pt_epoch_18.pt_epoch_20.pt_epoch_8.pt_epoch_2.pt_epoch_8.pt", batch_size=32, learning_rate=1e-5)
# Out:
# Using device: cuda
# Upsampling unique data segments...
# Upsampled 5695 unique spans to 10000 spans.
# Prepared 20000 windows from 1800 trials
# Resumed training from checkpoint: /content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt_epoch_35.pt_epoch_34.pt_epoch_18.pt_epoch_18.pt_epoch_20.pt_epoch_8.pt_epoch_2.pt_epoch_8.pt
#
# Starting training...
# Training: 100%|██████████| 562/562 [09:10<00:00,  1.02it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt_epoch_35.pt_epoch_34.pt_epoch_18.pt_epoch_18.pt_epoch_20.pt_epoch_8.pt_epoch_2.pt_epoch_8.pt_epoch_1.pt
# Epoch 1/2000 - Train Loss: -1.0217 | Val Loss: -1.1414
# Training: 100%|██████████| 562/562 [09:16<00:00,  1.01it/s]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt_epoch_35.pt_epoch_34.pt_epoch_18.pt_epoch_18.pt_epoch_20.pt_epoch_8.pt_epoch_2.pt_epoch_8.pt_epoch_2.pt
# ...
