# %%
# !pip install transformers

# %%
#Clone repo
import os
import shutil
if os.path.exists("/content/nnts"):
  shutil.rmtree("/content/nnts")

os.chdir("/content")
# !git clone https://github.com/smestern/nnts.git
# Out:
# Cloning into 'nnts'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 92 (delta 40), reused 70 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 932.69 KiB | 17.60 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
import os
os.chdir("/content/nnts/electrophysiology_transformer")

# %%
import train

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
train.main("/content/drive/MyDrive/nngan_trace_dataset_2000.joblib", "/content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt_epoch_35.pt_epoch_34.pt", batch_size=32, learning_rate=1e-4)
# Out:
# Using device: cuda
# Prepared 10000 windows from 1800 trials
# Resumed training from checkpoint: /content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt
#
# Starting training...
# Training: 100%|██████████| 281/281 [04:43<00:00,  1.01s/it]
# New best validation loss; checkpointed to /content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt_epoch_1.pt
# Epoch 1/2000 - Train Loss: -0.7474 | Val Loss: -0.9054
# Training: 100%|██████████| 281/281 [04:48<00:00,  1.03s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3125682589.py in <cell line: 0>()
# ----> 1 train.main("/content/drive/MyDrive/nngan_trace_dataset_2000.joblib", "/content/drive/MyDrive/nnts_checkpoints/best_val.pt_epoch_29.pt", batch_size=32)
#
# ...
